# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np
rate, data = wav.read('D:/TestApp/TestApp/build/tmp/TestApp/Debug/out.wav')
#rate, data = wav.read('sin.wav')
#rate, data = wav.read('noise.wav')
# rate, data = wav.read('test.wav')
print("signal /noise/")
plt.plot(data)
# plt.axis([0, 2000, -32000, 32000])
plt.show()
# print(rate)
# print(data.size)
print("FFT")
N = data.size
yf = fft(data)
xf = np.linspace(10000, rate/2, N//2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
# plt.axis([0, 4000, 0, 1000])
plt.grid()
plt.show()
# Out:
# signal /noise/
# FFT
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d4f204116c0e> in <module>
#      16 N = data.size
#      17 yf = fft(data)
# ---> 18 xf = np.linspace(10000, rate/2, N/2)
#      19 import matplotlib.pyplot as plt
#      20 plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# c:\python36x64\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     111
#     112     """
# --> 113     num = operator.index(num)
#     114     if num < 0:
#     115         raise ValueError("Number of samples, %s, must be non-negative." % num)
#
# TypeError: 'float' object cannot be interpreted as an integer
